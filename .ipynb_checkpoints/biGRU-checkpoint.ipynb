# %% [markdown]
# # Tweet Intent Classification with Twitter Dataset
# <hr>
#
# We will build a intent classification model using GRU model using twitter dataset. The dataset was scrapped using 'Twint'. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).

# %% [markdown]
# <hr>
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from sklearn.model_selection import KFold

# %%
## test GPU

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('dataset/tweetlabels1000_labeled.xlsx - Sheet2.csv')

# %%
print(df.shape)
df
# Out:
# (1003, 4)
#         No               Label     Username  \
# 0        0                none   chyrisalys
# 1        1  indirect complaint      woiidal
# 2        2              remark      ranieaw
# 3        3     negative remark      daeguv_
# 4        4  indirect complaint    fiorincha
# ...    ...                 ...          ...
# 998    998            campaign   sangwarior
# 999    999            campaign   sangwarior
# 1000  1000     negative remark    untextend
# 1001  1001            campaign   sangwarior
# 1002  1002             inquiry  narshashila
#
#                                                   Tweet
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   INDIHOME NGAPASIIII
# ...                                                 ...
# 998   Bisa sharing bareng sobat indihome gini kan as...
# 999   Sekarang nyantai dulu bentar sambil scroll sos...
# 1000  @JefriHandri Sini indihome down dr semalem jam...
# 1001  Ini barusan slesei sob... Lumayan buat nyari k...
# 1002          @IndiHomeCare daftar indihome lewat mana?
#
# [1003 rows x 4 columns]

# %%
# drop rows with label = campaign, own tweet, & incomplete
df = df.loc[~df['Label'].isin(['campaign','own tweet','incomplete'])].copy()
df
# Out:
#         No               Label       Username  \
# 0        0                none     chyrisalys
# 1        1  indirect complaint        woiidal
# 2        2              remark        ranieaw
# 3        3     negative remark        daeguv_
# 4        4  indirect complaint      fiorincha
# ...    ...                 ...            ...
# 994    994             inquiry   pecintamochi
# 995    995             inquiry  tetehaisyah51
# 997    997    direct complaint      untextend
# 1000  1000     negative remark      untextend
# 1002  1002             inquiry    narshashila
#
#                                                   Tweet
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   INDIHOME NGAPASIIII
# ...                                                 ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...
# 1000  @JefriHandri Sini indihome down dr semalem jam...
# 1002          @IndiHomeCare daftar indihome lewat mana?
#
# [722 rows x 4 columns]

# %%
# Label Encoding & drop columns
df['label'] = df['Label'].map({'indirect complaint': 0, 'remark': 1, 'negative remark': 2, 'direct compliment' : 3 , 'direct complaint' : 4, 'none' : 5, 'inquiry' : 6})
df.drop(['No', 'Label', 'Username'], axis=1, inplace=True)
df
# Out:
#                                                   Tweet  label
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
# [722 rows x 2 columns]

# %%
df.info()
df.groupby( by='label').count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 722 entries, 0 to 1002
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   722 non-null    object
#  1   label   722 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 16.9+ KB
#        Tweet
# label
# 0         68
# 1        153
# 2        128
# 3         64
# 4        110
# 5        123
# 6         76

# %%
# Separate the tweet and label
tweets, labels = list(df.Tweet), list(df.label)

# %%
tweets[123]
# Out:
# '@IndiHomeCare Halo min, wifi indihome LOS dari tadi siang! Ini gimna?? Urgent nih gw mau make!!  https://t.co/WRXvsHaAUJ'

# %% [markdown]
# ## Data Preprocessing
# <hr>
#
# for data preprocessing we will do:
# - Lower the letter case
# - Cleansing (remove ascii, digits, punctuations, extra whitespaces, urls)
# - Normalization Indonesian words
# - Stemming 'kata berimbuhan'
# - Tokenization
#
# The tokenization process will be handled by __Tokenizer__ class in TensorFlow
#
# <b>For padding sequence purpose, one way to choose the maximum sequence length is to just pick the length of the longest sentence in the training set.</b>

# %%
# to lowercase
df['tweet_lower'] = df['Tweet'].str.lower()
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
# [722 rows x 3 columns]

# %%
# Regex Manipulation for text cleansing
import re
import string

# %%
def text_cleansing(text):
    
       
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    
    # remove digits (using regex) -> subtitute
    text = re.sub('\d+', '', text)
    
    # remove punctuation, reference: https://stackoverflow.com/a/34294398
    # text = text.translate(str.maketrans('', '', string.punctuation))
    
    # remove whitespace in the beginning and end of sentence
    text = text.strip()
    
    # remove extra whitespace in the middle of sentence (using regex)
    text = re.sub('\s+', ' ', text)
    
    # remove url in tweet (using regex)
    text = re.sub(r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", "", text)
    
    # masking indihome
    text = re.sub(r"@indihome", "xxxindihomexxx", text)
    
    # remove url in tweet (using regex)
    text = re.sub(r"xxxindihomexxx\w+", "xxxindihomexxx", text)
    
    # masking user
    text = re.sub(r"@\w+", "xxxuserxxx", text)
    
    return text

# %%
# text_cleansing()
df['tweet_clean'] = df['tweet_lower'].apply(lambda x: text_cleansing(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
# [722 rows x 4 columns]

# %%
print(df['Tweet'][69])
print(df['Tweet'][63])
# Out:
# @bherlindayl @IndiHome  https://t.co/C07nnk5jkk
# @IndiHomeCare @IndiHome Mana. Masi lemot

# %%
print(df['tweet_clean'][69])
print(df['tweet_clean'][63])
# Out:
# xxxuserxxx xxxindihomexxx
# xxxindihomexxx xxxindihomexxx mana. masi lemot

# %%
# importing the module
import json
  
# reading the data from the file
with open('dataset/combined_slang_words.txt') as f:
    data = f.read()
       
# reconstructing the data as a dictionary
data_dict1 = json.loads(data)
  
len(data_dict1)
# Out:
# 1018

# %%
# normalization indonesian words
normalized_word = pd.read_csv('dataset/new_kamusalay.csv', header=None)
data_dict2 = dict(zip(normalized_word[0], normalized_word[1]))
len(data_dict2)
# Out:
# 15166

# %%
def normalize_text1(text):
    return ' '.join(data_dict1.get(word, word) for word in text.split())
def normalize_text2(text):
    return ' '.join(data_dict2.get(word, word) for word in text.split())

# %%
df['tweet_normalized1'] = df['tweet_clean'].apply(lambda x: normalize_text1(x))
df['tweet_normalized2'] = df['tweet_normalized1'].apply(lambda x: normalize_text1(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized1  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized2
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
# [722 rows x 6 columns]

# %%
# stemming 'kata berimbuhan'
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['tweet_stemmed'] = df['tweet_normalized2'].apply(lambda x: stemmer.stem(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized1  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized2  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                           tweet_stemmed
# 0                            wifi watcha pasti indihome
# 1                           indihome ada masalah apasih
# 2     sore sore hujan rebah bareng bocil nonton nuss...
# 3              indihome plis untuk tanggal jangan surup
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min kalau jatuh tempo bayar ind...
# 995   xxxindihomexxx min indihome tv bisa gak langga...
# 997   xxxindihomexxx xxxuserxxx dari semalem down ga...
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002          xxxindihomexxx daftar indihome lewat mana
#
# [722 rows x 7 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Before we fit the clean data to the model, let's explore insights from the data we have.

# %%
from collections import Counter

# function to count unique words
def counter_word(text):
    count = Counter()
    for sentence in text.values:
        for word in sentence.split():
            count[word] += 1
    return count

# %%
# find out how many unique words in our data
unique_words = counter_word(df['tweet_stemmed'])
len(unique_words)
# Out:
# 2233

# %%
# take a look at the twenty most common words
unique_words.most_common(20)
# Out:
# [('indihome', 615),
#  ('xxxindihomexxx', 320),
#  ('xxxuserxxx', 318),
#  ('ini', 168),
#  ('di', 146),
#  ('saya', 143),
#  ('yang', 142),
#  ('kalau', 102),
#  ('sudah', 95),
#  ('pakai', 95),
#  ('dan', 88),
#  ('ada', 85),
#  ('banget', 84),
#  ('bisa', 81),
#  ('lagi', 76),
#  ('hari', 69),
#  ('saja', 67),
#  ('ga', 66),
#  ('tidak', 66),
#  ('juga', 62)]

# %%
# create a frequency table of word frequency
freq = [freq for word, freq in unique_words.items()]
top_unique=max(pd.Series(freq).value_counts())
top_unique
# Out:
# 1292

# %%
# your code here
sentence_length = df['tweet_stemmed'].apply(lambda x: len(x.split()))

# %%
# seaborn
sns.histplot(sentence_length, binwidth=1)
# Out:
# <AxesSubplot:xlabel='tweet_stemmed', ylabel='Count'>

# %%
# five number summary
sentence_length.describe()
# Out:
# count    722.000000
# mean      14.344875
# std       10.490940
# min        2.000000
# 25%        6.000000
# 50%       11.000000
# 75%       19.000000
# max       47.000000
# Name: tweet_stemmed, dtype: float64

# %%
# define number of words to keep during conversion (can be tuned)
num_words = len(unique_words)-top_unique
num_words
# Out:
# 941

# %% [markdown]
# ## Bidirectional GRU Model with Random Embedding

# %%
# Define a function to compute the max length of sequence
def max_length(sequences):
    '''
    input:
        sequences: a 2D list of integer sequences
    output:
        max_length: the max length of the sequences
    '''
    max_length = 0
    for i, seq in enumerate(sequences):
        length = len(seq)
        if max_length < length:
            max_length = length
    return max_length

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.constraints import MaxNorm

def define_model(input_dim = None, output_dim=300, max_length = None ):
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Embedding(input_dim=input_dim, 
                                  mask_zero= True,
                                  output_dim=output_dim, 
                                  input_length=max_length, 
                                  input_shape=(max_length, )),
        tf.keras.layers.Bidirectional((tf.keras.layers.GRU(units=64, return_sequences=True))),
        tf.keras.layers.Bidirectional((tf.keras.layers.GRU(units=64, return_sequences=False))),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=7, activation='sigmoid')
    ])
    
    model.compile( loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
class myCallback(tf.keras.callbacks.Callback):
    # Overide the method on_epoch_end() for our benefit
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('accuracy') > 0.93):
            print("\nReached 93% accuracy so cancelling training!")
            self.model.stop_training=True


callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0, 
                                             patience=10, verbose=2, 
                                             mode='auto', restore_best_weights=True)

# %% [markdown]
# ## Train and Test the model Using 10-Fold cross validation

# %%
from keras.utils.np_utils import to_categorical
from keras.preprocessing.text import Tokenizer

# Parameter Initialization
trunc_type='post'
padding_type='post'
oov_tok = "<UNK>"

columns = ['acc1', 'acc2', 'acc3', 'acc4', 'acc5', 'acc6', 'acc7', 'acc8', 'acc9', 'acc10', 'AVG']
record = pd.DataFrame(columns = columns)

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(n_splits=10, shuffle=False, random_state=None)

# Separate the tweet and label
tweets, labels = list(df.tweet_stemmed), list(df.label)

exp=0

# kfold.split() will return set indices for each split
acc_list = []
for train, test in kfold.split(tweets):
    
    exp+=1
    print('Training {}: '.format(exp))
    
    train_x, test_x = [], []
    train_y, test_y = [], []

    for i in train:
        train_x.append(tweets[i])
        train_y.append(labels[i])

    for i in test:
        test_x.append(tweets[i])
        test_y.append(labels[i])

    # Turn the labels into a numpy array
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # one-hot
    onehot_train_y = to_categorical(train_y)
    onehot_test_y = to_categorical(test_y)

    # encode data using Cleaning and Tokenization
    tokenizer = Tokenizer(num_words=num_words,oov_token=oov_tok)
    tokenizer.fit_on_texts(train_x)

    # Turn the text into sequence
    training_sequences = tokenizer.texts_to_sequences(train_x)
    test_sequences = tokenizer.texts_to_sequences(test_x)

    max_len = max_length(training_sequences)

    # Pad the sequence to have the same size
    Xtrain = pad_sequences(training_sequences, maxlen=max_len, padding=padding_type, truncating=trunc_type)
    Xtest = pad_sequences(test_sequences, maxlen=max_len, padding=padding_type, truncating=trunc_type)

    word_index = tokenizer.word_index
    vocab_size = len(word_index)+1

    # Define the input shape
    model = define_model(input_dim=vocab_size, max_length=max_len)

    # Train the model
    model.fit(Xtrain, onehot_train_y, batch_size=32, epochs=30, verbose=1, 
              callbacks=[callbacks], validation_data=(Xtest, onehot_test_y))

    # evaluate the model
    loss, acc = model.evaluate(Xtest, onehot_test_y, verbose=0)
    print('Test Accuracy: {}'.format(acc*100))

    acc_list.append(acc*100)

mean_acc = np.array(acc_list).mean()
entries = acc_list + [mean_acc]

temp = pd.DataFrame([entries], columns=columns)
record = record.append(temp, ignore_index=True)
print()
print(record)
print()
# Out:
# Training 1:
# Epoch 1/30
# 21/21 [==============================] - 23s 227ms/step - loss: 1.8812 - accuracy: 0.2681 - val_loss: 1.9465 - val_accuracy: 0.2192
# Epoch 2/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.6179 - accuracy: 0.4361 - val_loss: 1.8054 - val_accuracy: 0.3562
# Epoch 3/30
# 21/21 [==============================] - 1s 32ms/step - loss: 1.2391 - accuracy: 0.5393 - val_loss: 1.5935 - val_accuracy: 0.4247
# Epoch 4/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.9111 - accuracy: 0.6718 - val_loss: 1.5020 - val_accuracy: 0.3562
# Epoch 5/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.6419 - accuracy: 0.7781 - val_loss: 1.7572 - val_accuracy: 0.4110
# Epoch 6/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.4314 - accuracy: 0.8536 - val_loss: 1.8635 - val_accuracy: 0.3973
# Epoch 7/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.3190 - accuracy: 0.9029 - val_loss: 2.4332 - val_accuracy: 0.3836
# Epoch 8/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.2610 - accuracy: 0.9199 - val_loss: 2.5719 - val_accuracy: 0.3836
# Epoch 9/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.2006 - accuracy: 0.9399 - val_loss: 2.8967 - val_accuracy: 0.3699
# Epoch 10/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1648 - accuracy: 0.9507 - val_loss: 3.1144 - val_accuracy: 0.3699
# Epoch 11/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1295 - accuracy: 0.9584 - val_loss: 3.1709 - val_accuracy: 0.4384
# Epoch 12/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1108 - accuracy: 0.9630 - val_loss: 3.3101 - val_accuracy: 0.3973
# Epoch 13/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1226 - accuracy: 0.9676 - val_loss: 3.4845 - val_accuracy: 0.4110
# Epoch 14/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1018 - accuracy: 0.9599 - val_loss: 3.8212 - val_accuracy: 0.3699
# Epoch 15/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0907 - accuracy: 0.9692 - val_loss: 3.7021 - val_accuracy: 0.3699
# Epoch 16/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0861 - accuracy: 0.9769 - val_loss: 3.8388 - val_accuracy: 0.3425
# Epoch 17/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0854 - accuracy: 0.9723 - val_loss: 3.9473 - val_accuracy: 0.3562
# Epoch 18/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0733 - accuracy: 0.9769 - val_loss: 4.0728 - val_accuracy: 0.3699
# Epoch 19/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0708 - accuracy: 0.9784 - val_loss: 4.0670 - val_accuracy: 0.3699
# Epoch 20/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0606 - accuracy: 0.9784 - val_loss: 4.1481 - val_accuracy: 0.3425
# Epoch 21/30
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0777 - accuracy: 0.9719 ETA: 0s - loss: 0.0751 - accuracy: 0.Restoring model weights from the end of the best epoch: 11.
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0771 - accuracy: 0.9723 - val_loss: 4.2187 - val_accuracy: 0.3699
# Epoch 00021: early stopping
# Test Accuracy: 43.83561611175537
# Training 2:
# Epoch 1/30
# 21/21 [==============================] - 16s 234ms/step - loss: 1.8913 - accuracy: 0.2435 - val_loss: 1.8714 - val_accuracy: 0.2192
# Epoch 2/30
# 21/21 [==============================] - 1s 33ms/step - loss: 1.6440 - accuracy: 0.4068 - val_loss: 1.6514 - val_accuracy: 0.3699
# Epoch 3/30
# 21/21 [==============================] - 1s 32ms/step - loss: 1.3185 - accuracy: 0.5146 - val_loss: 1.6287 - val_accuracy: 0.3425
# Epoch 4/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.0241 - accuracy: 0.6163 - val_loss: 1.6246 - val_accuracy: 0.4110
# Epoch 5/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.7636 - accuracy: 0.7519 - val_loss: 1.7233 - val_accuracy: 0.4521
# Epoch 6/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5184 - accuracy: 0.8120 - val_loss: 1.9570 - val_accuracy: 0.3836
# Epoch 7/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.3847 - accuracy: 0.8921 - val_loss: 2.2251 - val_accuracy: 0.3973
# Epoch 8/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.2726 - accuracy: 0.9199 - val_loss: 2.6387 - val_accuracy: 0.4384
# Epoch 9/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.2101 - accuracy: 0.9230 - val_loss: 3.0807 - val_accuracy: 0.3288
# Epoch 10/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.1931 - accuracy: 0.9430 - val_loss: 2.8413 - val_accuracy: 0.3836
# Epoch 11/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.1530 - accuracy: 0.9569 - val_loss: 3.2061 - val_accuracy: 0.3425
# Epoch 12/30
# 21/21 [==============================] - 1s 34ms/step - loss: 0.1506 - accuracy: 0.9522 - val_loss: 3.2760 - val_accuracy: 0.3699
# Epoch 13/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1432 - accuracy: 0.9507 - val_loss: 3.3643 - val_accuracy: 0.3562
# Epoch 14/30
# 21/21 [==============================] - 1s 35ms/step - loss: 0.1200 - accuracy: 0.9584 - val_loss: 3.3367 - val_accuracy: 0.3425
# Epoch 15/30
# 19/21 [==========================>...] - ETA: 0s - loss: 0.1009 - accuracy: 0.9688Restoring model weights from the end of the best epoch: 5.
# 21/21 [==============================] - 1s 33ms/step - loss: 0.1011 - accuracy: 0.9707 - val_loss: 3.4783 - val_accuracy: 0.3425
# Epoch 00015: early stopping
# Test Accuracy: 45.205479860305786
# Training 3:
# Epoch 1/30
# 21/21 [==============================] - 18s 271ms/step - loss: 1.8899 - accuracy: 0.2692 - val_loss: 1.8152 - val_accuracy: 0.3333
# Epoch 2/30
# 21/21 [==============================] - 1s 37ms/step - loss: 1.6028 - accuracy: 0.4308 - val_loss: 1.6527 - val_accuracy: 0.4028
# Epoch 3/30
# 21/21 [==============================] - 1s 37ms/step - loss: 1.2680 - accuracy: 0.5215 - val_loss: 1.4997 - val_accuracy: 0.4306
# Epoch 4/30
# 21/21 [==============================] - 1s 35ms/step - loss: 0.9556 - accuracy: 0.6369 - val_loss: 1.5633 - val_accuracy: 0.4306
# Epoch 5/30
# 21/21 [==============================] - 1s 37ms/step - loss: 0.6559 - accuracy: 0.7877 - val_loss: 1.5985 - val_accuracy: 0.5000
# Epoch 6/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5103 - accuracy: 0.8400 - val_loss: 1.7402 - val_accuracy: 0.4722
# Epoch 7/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.3622 - accuracy: 0.8969 - val_loss: 1.9360 - val_accuracy: 0.4861
# Epoch 8/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.2877 - accuracy: 0.9062 - val_loss: 2.0722 - val_accuracy: 0.4306
# Epoch 9/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2087 - accuracy: 0.9477 - val_loss: 2.2117 - val_accuracy: 0.5000
# Epoch 10/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.93 - 1s 30ms/step - loss: 0.1793 - accuracy: 0.9385 - val_loss: 2.4913 - val_accuracy: 0.5000
# Epoch 11/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1641 - accuracy: 0.9462 - val_loss: 2.5876 - val_accuracy: 0.4167
# Epoch 12/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.1282 - accuracy: 0.9600 - val_loss: 2.6368 - val_accuracy: 0.4583
# Epoch 13/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1171 - accuracy: 0.9600 - val_loss: 2.8552 - val_accuracy: 0.4722
# Epoch 14/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1135 - accuracy: 0.9677 - val_loss: 2.9904 - val_accuracy: 0.4583
# Epoch 15/30
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0932 - accuracy: 0.9781Restoring model weights from the end of the best epoch: 5.
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0922 - accuracy: 0.9785 - val_loss: 3.0309 - val_accuracy: 0.4444
# Epoch 00015: early stopping
# Test Accuracy: 50.0
# Training 4:
# Epoch 1/30
# 21/21 [==============================] - 16s 225ms/step - loss: 1.8790 - accuracy: 0.3031 - val_loss: 1.8256 - val_accuracy: 0.2917
# Epoch 2/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.5863 - accuracy: 0.4323 - val_loss: 1.6415 - val_accuracy: 0.3750
# Epoch 3/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.2579 - accuracy: 0.5354 - val_loss: 1.6893 - val_accuracy: 0.3889
# Epoch 4/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.9326 - accuracy: 0.6677 - val_loss: 1.8626 - val_accuracy: 0.3611
# Epoch 5/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6842 - accuracy: 0.7569 - val_loss: 2.1289 - val_accuracy: 0.3472
# Epoch 6/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.4723 - accuracy: 0.8492 - val_loss: 2.3605 - val_accuracy: 0.4028
# Epoch 7/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.3251 - accuracy: 0.9031 - val_loss: 2.2943 - val_accuracy: 0.3611
# Epoch 8/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2502 - accuracy: 0.9185 - val_loss: 2.6979 - val_accuracy: 0.3056
# Epoch 9/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1972 - accuracy: 0.9554 - val_loss: 2.7635 - val_accuracy: 0.2639
# Epoch 10/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1752 - accuracy: 0.9462 - val_loss: 3.4371 - val_accuracy: 0.2917
# Epoch 11/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1306 - accuracy: 0.9585 - val_loss: 3.2844 - val_accuracy: 0.2639
# Epoch 12/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1197 - accuracy: 0.9692 - val_loss: 3.8002 - val_accuracy: 0.2639
# Epoch 13/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0877 - accuracy: 0.9769 - val_loss: 3.2892 - val_accuracy: 0.3194
# Epoch 14/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0797 - accuracy: 0.9738 - val_loss: 3.7977 - val_accuracy: 0.2917
# Epoch 15/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0742 - accuracy: 0.9738 - val_loss: 3.9584 - val_accuracy: 0.2917
# Epoch 16/30
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0849 - accuracy: 0.9770Restoring model weights from the end of the best epoch: 6.
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0825 - accuracy: 0.9769 - val_loss: 4.0900 - val_accuracy: 0.2778
# Epoch 00016: early stopping
# Test Accuracy: 40.27777910232544
# Training 5:
# Epoch 1/30
# 21/21 [==============================] - 17s 270ms/step - loss: 1.8931 - accuracy: 0.2846 - val_loss: 1.7864 - val_accuracy: 0.4444
# Epoch 2/30
# 21/21 [==============================] - 1s 36ms/step - loss: 1.6498 - accuracy: 0.4492 - val_loss: 1.5551 - val_accuracy: 0.4722
# Epoch 3/30
# 21/21 [==============================] - 1s 39ms/step - loss: 1.3067 - accuracy: 0.5200 - val_loss: 1.6642 - val_accuracy: 0.3611
# Epoch 4/30
# 21/21 [==============================] - 1s 35ms/step - loss: 1.0450 - accuracy: 0.5985 - val_loss: 1.6041 - val_accuracy: 0.3889
# Epoch 5/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.7330 - accuracy: 0.7508 - val_loss: 1.7256 - val_accuracy: 0.4167
# Epoch 6/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5030 - accuracy: 0.8308 - val_loss: 2.0597 - val_accuracy: 0.3194
# Epoch 7/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.3456 - accuracy: 0.8969 - val_loss: 2.2303 - val_accuracy: 0.3611
# Epoch 8/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.2425 - accuracy: 0.9292 - val_loss: 2.3990 - val_accuracy: 0.3750
# Epoch 9/30
# 21/21 [==============================] - 1s 35ms/step - loss: 0.1928 - accuracy: 0.9354 - val_loss: 2.7403 - val_accuracy: 0.3333
# Epoch 10/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1626 - accuracy: 0.9508 - val_loss: 2.8201 - val_accuracy: 0.3472
# Epoch 11/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.1464 - accuracy: 0.9538 - val_loss: 3.1005 - val_accuracy: 0.3750
# Epoch 12/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9646Restoring model weights from the end of the best epoch: 2.
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1371 - accuracy: 0.9646 - val_loss: 3.0281 - val_accuracy: 0.4028
# Epoch 00012: early stopping
# Test Accuracy: 47.22222089767456
# Training 6:
# Epoch 1/30
# 21/21 [==============================] - 17s 231ms/step - loss: 1.8812 - accuracy: 0.2923 - val_loss: 1.7820 - val_accuracy: 0.3056
# Epoch 2/30
# 21/21 [==============================] - 1s 33ms/step - loss: 1.6654 - accuracy: 0.3831 - val_loss: 1.4661 - val_accuracy: 0.4861
# Epoch 3/30
# 21/21 [==============================] - 1s 40ms/step - loss: 1.3203 - accuracy: 0.5338 - val_loss: 1.2714 - val_accuracy: 0.5972
# Epoch 4/30
# 21/21 [==============================] - 1s 41ms/step - loss: 1.0144 - accuracy: 0.6400 - val_loss: 1.2026 - val_accuracy: 0.5278
# Epoch 5/30
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6870 - accuracy: 0.7723 - val_loss: 1.2797 - val_accuracy: 0.5417
# Epoch 6/30
# 21/21 [==============================] - 1s 34ms/step - loss: 0.4686 - accuracy: 0.8477 - val_loss: 1.4219 - val_accuracy: 0.4444
# Epoch 7/30
# 21/21 [==============================] - 1s 34ms/step - loss: 0.3326 - accuracy: 0.8969 - val_loss: 1.5350 - val_accuracy: 0.5556
# Epoch 8/30
# 21/21 [==============================] - 1s 35ms/step - loss: 0.2574 - accuracy: 0.9000 - val_loss: 1.7082 - val_accuracy: 0.4861
# Epoch 9/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.2160 - accuracy: 0.9292 - val_loss: 1.7619 - val_accuracy: 0.5000
# Epoch 10/30
# 21/21 [==============================] - 1s 35ms/step - loss: 0.1687 - accuracy: 0.9554 - val_loss: 1.9339 - val_accuracy: 0.5139
# Epoch 11/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1470 - accuracy: 0.9538 - val_loss: 2.0715 - val_accuracy: 0.4722
# Epoch 12/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1149 - accuracy: 0.9615 - val_loss: 2.1398 - val_accuracy: 0.5000
# Epoch 13/30
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0990 - accuracy: 0.9688Restoring model weights from the end of the best epoch: 3.
# 21/21 [==============================] - 1s 32ms/step - loss: 0.0979 - accuracy: 0.9677 - val_loss: 2.2168 - val_accuracy: 0.5000
# Epoch 00013: early stopping
# Test Accuracy: 59.72222089767456
# Training 7:
# Epoch 1/30
# 21/21 [==============================] - 18s 246ms/step - loss: 1.8969 - accuracy: 0.2277 - val_loss: 1.7271 - val_accuracy: 0.3750
# Epoch 2/30
# 21/21 [==============================] - 1s 34ms/step - loss: 1.6776 - accuracy: 0.3708 - val_loss: 1.4793 - val_accuracy: 0.4444
# Epoch 3/30
# 21/21 [==============================] - 1s 34ms/step - loss: 1.3527 - accuracy: 0.4877 - val_loss: 1.3877 - val_accuracy: 0.5417
# Epoch 4/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.0416 - accuracy: 0.6400 - val_loss: 1.3392 - val_accuracy: 0.4861
# Epoch 5/30
# 21/21 [==============================] - 1s 34ms/step - loss: 0.7636 - accuracy: 0.7169 - val_loss: 1.3674 - val_accuracy: 0.5000
# Epoch 6/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.5147 - accuracy: 0.8400 - val_loss: 1.4398 - val_accuracy: 0.5000
# Epoch 7/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.3388 - accuracy: 0.9031 - val_loss: 1.6475 - val_accuracy: 0.4583
# Epoch 8/30
# 21/21 [==============================] - 1s 35ms/step - loss: 0.2621 - accuracy: 0.9169 - val_loss: 1.7279 - val_accuracy: 0.4861
# Epoch 9/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1942 - accuracy: 0.9446 - val_loss: 1.6697 - val_accuracy: 0.5139
# Epoch 10/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1536 - accuracy: 0.9538 - val_loss: 2.0318 - val_accuracy: 0.4444
# Epoch 11/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1413 - accuracy: 0.9554 - val_loss: 2.0335 - val_accuracy: 0.4444
# Epoch 12/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1465 - accuracy: 0.9508 - val_loss: 1.9289 - val_accuracy: 0.4861
# Epoch 13/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9600Restoring model weights from the end of the best epoch: 3.
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1262 - accuracy: 0.9600 - val_loss: 1.9980 - val_accuracy: 0.4444
# Epoch 00013: early stopping
# Test Accuracy: 54.16666865348816
# Training 8:
# Epoch 1/30
# 21/21 [==============================] - 17s 230ms/step - loss: 1.8938 - accuracy: 0.2708 - val_loss: 1.7484 - val_accuracy: 0.4722
# Epoch 2/30
# 21/21 [==============================] - 1s 32ms/step - loss: 1.6566 - accuracy: 0.4015 - val_loss: 1.3985 - val_accuracy: 0.5833
# Epoch 3/30
# 21/21 [==============================] - 1s 33ms/step - loss: 1.2997 - accuracy: 0.5554 - val_loss: 1.3218 - val_accuracy: 0.5556
# Epoch 4/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.9645 - accuracy: 0.6492 - val_loss: 1.4042 - val_accuracy: 0.3611
# Epoch 5/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6883 - accuracy: 0.7569 - val_loss: 1.5908 - val_accuracy: 0.4028
# Epoch 6/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.4887 - accuracy: 0.8385 - val_loss: 1.8023 - val_accuracy: 0.3194
# Epoch 7/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.3447 - accuracy: 0.8938 - val_loss: 2.0620 - val_accuracy: 0.3194
# Epoch 8/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.2636 - accuracy: 0.9092 - val_loss: 1.9368 - val_accuracy: 0.3611
# Epoch 9/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.2348 - accuracy: 0.9369 - val_loss: 2.4217 - val_accuracy: 0.3750
# Epoch 10/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1921 - accuracy: 0.9354 - val_loss: 2.1238 - val_accuracy: 0.4306
# Epoch 11/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1518 - accuracy: 0.9492 - val_loss: 2.4525 - val_accuracy: 0.4444
# Epoch 12/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9554Restoring model weights from the end of the best epoch: 2.
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1295 - accuracy: 0.9554 - val_loss: 2.8547 - val_accuracy: 0.3472
# Epoch 00012: early stopping
# Test Accuracy: 58.33333134651184
# Training 9:
# Epoch 1/30
# 21/21 [==============================] - 17s 224ms/step - loss: 1.8846 - accuracy: 0.2569 - val_loss: 1.6904 - val_accuracy: 0.3472
# Epoch 2/30
# 21/21 [==============================] - 1s 30ms/step - loss: 1.6117 - accuracy: 0.4523 - val_loss: 1.4724 - val_accuracy: 0.3472
# Epoch 3/30
# 21/21 [==============================] - 1s 30ms/step - loss: 1.2492 - accuracy: 0.5338 - val_loss: 1.7068 - val_accuracy: 0.3750
# Epoch 4/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.9231 - accuracy: 0.6615 - val_loss: 1.7611 - val_accuracy: 0.4167
# Epoch 5/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6877 - accuracy: 0.7923 - val_loss: 1.9563 - val_accuracy: 0.3611
# Epoch 6/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.4751 - accuracy: 0.8385 - val_loss: 2.2869 - val_accuracy: 0.3472
# Epoch 7/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.3514 - accuracy: 0.8892 - val_loss: 2.5432 - val_accuracy: 0.4028
# Epoch 8/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2691 - accuracy: 0.9123 - val_loss: 2.6596 - val_accuracy: 0.2778
# Epoch 9/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.2012 - accuracy: 0.9400 - val_loss: 2.8547 - val_accuracy: 0.3472
# Epoch 10/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.1587 - accuracy: 0.9431 - val_loss: 2.9732 - val_accuracy: 0.3611
# Epoch 11/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1322 - accuracy: 0.9538 - val_loss: 3.2775 - val_accuracy: 0.3194
# Epoch 12/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1059 - accuracy: 0.9677 - val_loss: 3.5120 - val_accuracy: 0.3194
# Epoch 13/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.0905 - accuracy: 0.9723 - val_loss: 3.4198 - val_accuracy: 0.3194
# Epoch 14/30
# 21/21 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9800Restoring model weights from the end of the best epoch: 4.
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0753 - accuracy: 0.9800 - val_loss: 3.4013 - val_accuracy: 0.3056
# Epoch 00014: early stopping
# Test Accuracy: 41.66666567325592
# Training 10:
# Epoch 1/30
# 21/21 [==============================] - 16s 218ms/step - loss: 1.8767 - accuracy: 0.2631 - val_loss: 1.8544 - val_accuracy: 0.2083
# Epoch 2/30
# 21/21 [==============================] - 1s 30ms/step - loss: 1.6419 - accuracy: 0.4338 - val_loss: 1.6210 - val_accuracy: 0.2778
# Epoch 3/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.2955 - accuracy: 0.5338 - val_loss: 1.5145 - val_accuracy: 0.4167
# Epoch 4/30
# 21/21 [==============================] - 1s 33ms/step - loss: 0.9824 - accuracy: 0.6415 - val_loss: 1.5076 - val_accuracy: 0.4444
# Epoch 5/30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6943 - accuracy: 0.7554 - val_loss: 1.8310 - val_accuracy: 0.4306
# Epoch 6/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.4813 - accuracy: 0.8523 - val_loss: 2.0912 - val_accuracy: 0.4028
# Epoch 7/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.3478 - accuracy: 0.8892 - val_loss: 2.2717 - val_accuracy: 0.3750
# Epoch 8/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.2694 - accuracy: 0.9200 - val_loss: 2.3112 - val_accuracy: 0.3750
# Epoch 9/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2419 - accuracy: 0.9277 - val_loss: 2.6483 - val_accuracy: 0.3333
# Epoch 10/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1971 - accuracy: 0.9415 - val_loss: 2.6871 - val_accuracy: 0.3750
# Epoch 11/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1678 - accuracy: 0.9431 - val_loss: 2.9476 - val_accuracy: 0.3333
# Epoch 12/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1455 - accuracy: 0.9538 - val_loss: 3.0794 - val_accuracy: 0.3611
# Epoch 13/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1211 - accuracy: 0.9615 - val_loss: 3.2055 - val_accuracy: 0.3056
# Epoch 14/30
# 19/21 [==========================>...] - ETA: 0s - loss: 0.1317 - accuracy: 0.9589Restoring model weights from the end of the best epoch: 4.
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1288 - accuracy: 0.9600 - val_loss: 3.1599 - val_accuracy: 0.4028
# Epoch 00014: early stopping
# Test Accuracy: 44.44444477558136
#
#         acc1      acc2  acc3       acc4       acc5       acc6       acc7  \
# 0  43.835616  45.20548  50.0  40.277779  47.222221  59.722221  54.166669
#
#         acc8       acc9      acc10        AVG
# 0  58.333331  41.666666  44.444445  48.487443
# C:\Users\baktistr\AppData\Local\Temp\ipykernel_12936\3793454115.py:80: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   record = record.append(temp, ignore_index=True)

# %%
record
# Out:
#         acc1      acc2  acc3       acc4       acc5       acc6       acc7  \
# 0  43.835616  45.20548  50.0  40.277779  47.222221  59.722221  54.166669
#
#         acc8       acc9      acc10        AVG
# 0  58.333331  41.666666  44.444445  48.487443

# %% [markdown]
# report = record
# report = report.to_excel('GRU.xlsx', sheet_name='random')

# %% [markdown]
# ## Predict new tweet

# %%
# define the preprocessing pipeline
def text_preprocessing(text):
    # case folding
    text = text.lower()
    
    # text cleansing
    text = text_cleansing(text)
    
    # text normalization
    text = normalize_text1(text)
    
     # text normalization
    text = normalize_text2(text)
    
    # stemming
    text = stemmer.stem(text)
    
    return text

# %%
# predicting a text
from keras.utils.np_utils import to_categorical

def text_predict(text):
    
    # preprocess
    text_cleaned = text_preprocessing(text)
    text_sequence = tokenizer.texts_to_sequences([text_cleaned])

    max_len= max_length(training_sequences)

    seq_padded = pad_sequences(text_sequence, maxlen=max_len, padding=padding_type, truncating=trunc_type)

    # prediction
    pred_proba = model.predict(seq_padded)

    result = np.argmax(pred_proba)

    return result

# %%
# predicting data set

df['tweet_predict'] = df['tweet_stemmed'].apply(lambda x: text_predict(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized1  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized2  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                           tweet_stemmed  tweet_predict
# 0                            wifi watcha pasti indihome              2
# 1                           indihome ada masalah apasih              2
# 2     sore sore hujan rebah bareng bocil nonton nuss...              1
# 3              indihome plis untuk tanggal jangan surup              4
# 4                                   indihome ngapasiiii              2
# ...                                                 ...            ...
# 994   xxxindihomexxx min kalau jatuh tempo bayar ind...              6
# 995   xxxindihomexxx min indihome tv bisa gak langga...              4
# 997   xxxindihomexxx xxxuserxxx dari semalem down ga...              6
# 1000  xxxuserxxx sini indihome down dr semalem jam a...              2
# 1002          xxxindihomexxx daftar indihome lewat mana              6
#
# [722 rows x 8 columns]

# %%
# confusion matrix  
# source: https://datatofish.com/confusion-matrix-python/

confusion_matrix = pd.crosstab(df['label'], df['tweet_predict'], rownames=['Actual'], colnames=['Predicted'])

sns.heatmap(confusion_matrix, annot=True)
plt.show()

# labels:
        #0: indirect complaint
        #1: remark
        #2: negative remark
        #3: direct compliment
        #4: direct complaint
        #5: none
        #6: inquiry

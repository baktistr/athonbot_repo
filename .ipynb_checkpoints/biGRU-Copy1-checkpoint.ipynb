# %% [markdown]
# # Tweet Intent Classification with Twitter Dataset
# <hr>
#
# We will build a intent classification model using GRU model using twitter dataset. The dataset was scrapped using 'Twint'. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).

# %% [markdown]
# <hr>
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from sklearn.model_selection import KFold

# %%
## test GPU

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('dataset/tweetlabels1000_labeled.xlsx - Sheet2.csv')

# %%
print(df.shape)
df
# Out:
# (1003, 4)
#         No               Label     Username  \
# 0        0                none   chyrisalys
# 1        1  indirect complaint      woiidal
# 2        2              remark      ranieaw
# 3        3     negative remark      daeguv_
# 4        4  indirect complaint    fiorincha
# ...    ...                 ...          ...
# 998    998            campaign   sangwarior
# 999    999            campaign   sangwarior
# 1000  1000     negative remark    untextend
# 1001  1001            campaign   sangwarior
# 1002  1002             inquiry  narshashila
#
#                                                   Tweet
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   INDIHOME NGAPASIIII
# ...                                                 ...
# 998   Bisa sharing bareng sobat indihome gini kan as...
# 999   Sekarang nyantai dulu bentar sambil scroll sos...
# 1000  @JefriHandri Sini indihome down dr semalem jam...
# 1001  Ini barusan slesei sob... Lumayan buat nyari k...
# 1002          @IndiHomeCare daftar indihome lewat mana?
#
# [1003 rows x 4 columns]

# %%
# drop rows with label = campaign, own tweet, & incomplete
df = df.loc[~df['Label'].isin(['campaign','own tweet','incomplete'])].copy()
df
# Out:
#         No               Label       Username  \
# 0        0                none     chyrisalys
# 1        1  indirect complaint        woiidal
# 2        2              remark        ranieaw
# 3        3     negative remark        daeguv_
# 4        4  indirect complaint      fiorincha
# ...    ...                 ...            ...
# 994    994             inquiry   pecintamochi
# 995    995             inquiry  tetehaisyah51
# 997    997    direct complaint      untextend
# 1000  1000     negative remark      untextend
# 1002  1002             inquiry    narshashila
#
#                                                   Tweet
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   INDIHOME NGAPASIIII
# ...                                                 ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...
# 1000  @JefriHandri Sini indihome down dr semalem jam...
# 1002          @IndiHomeCare daftar indihome lewat mana?
#
# [722 rows x 4 columns]

# %%
# Label Encoding & drop columns
df['label'] = df['Label'].map({'indirect complaint': 0, 'remark': 1, 'negative remark': 2, 'direct compliment' : 3 , 'direct complaint' : 4, 'none' : 5, 'inquiry' : 6})
df.drop(['No', 'Label', 'Username'], axis=1, inplace=True)
df
# Out:
#                                                   Tweet  label
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
# [722 rows x 2 columns]

# %%
df.info()
df.groupby( by='label').count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 722 entries, 0 to 1002
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   722 non-null    object
#  1   label   722 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 16.9+ KB
#        Tweet
# label
# 0         68
# 1        153
# 2        128
# 3         64
# 4        110
# 5        123
# 6         76

# %%
# Separate the tweet and label
tweets, labels = list(df.Tweet), list(df.label)

# %%
tweets[123]
# Out:
# '@IndiHomeCare Halo min, wifi indihome LOS dari tadi siang! Ini gimna?? Urgent nih gw mau make!!  https://t.co/WRXvsHaAUJ'

# %% [markdown]
# ## Data Preprocessing
# <hr>
#
# for data preprocessing we will do:
# - Lower the letter case
# - Cleansing (remove ascii, digits, punctuations, extra whitespaces, urls)
# - Normalization Indonesian words
# - Stemming 'kata berimbuhan'
# - Tokenization
#
# The tokenization process will be handled by __Tokenizer__ class in TensorFlow
#
# <b>For padding sequence purpose, one way to choose the maximum sequence length is to just pick the length of the longest sentence in the training set.</b>

# %%
# to lowercase
df['tweet_lower'] = df['Tweet'].str.lower()
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
# [722 rows x 3 columns]

# %%
# Regex Manipulation for text cleansing
import re
import string

# %%
def text_cleansing(text):
    
       
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    
    # remove digits (using regex) -> subtitute
    text = re.sub('\d+', '', text)
    
    # remove punctuation, reference: https://stackoverflow.com/a/34294398
    # text = text.translate(str.maketrans('', '', string.punctuation))
    
    # remove whitespace in the beginning and end of sentence
    text = text.strip()
    
    # remove extra whitespace in the middle of sentence (using regex)
    text = re.sub('\s+', ' ', text)
    
    # remove url in tweet (using regex)
    text = re.sub(r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", "", text)
    
    # masking indihome
    text = re.sub(r"@indihome", "xxxindihomexxx", text)
    
    # remove url in tweet (using regex)
    text = re.sub(r"xxxindihomexxx\w+", "xxxindihomexxx", text)
    
    # masking user
    text = re.sub(r"@\w+", "xxxuserxxx", text)
    
    return text

# %%
# text_cleansing()
df['tweet_clean'] = df['tweet_lower'].apply(lambda x: text_cleansing(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
# [722 rows x 4 columns]

# %%
print(df['Tweet'][69])
print(df['Tweet'][63])
# Out:
# @bherlindayl @IndiHome  https://t.co/C07nnk5jkk
# @IndiHomeCare @IndiHome Mana. Masi lemot

# %%
print(df['tweet_clean'][69])
print(df['tweet_clean'][63])
# Out:
# xxxuserxxx xxxindihomexxx
# xxxindihomexxx xxxindihomexxx mana. masi lemot

# %%
# importing the module
import json
  
# reading the data from the file
with open('dataset/combined_slang_words.txt') as f:
    data = f.read()
       
# reconstructing the data as a dictionary
data_dict1 = json.loads(data)
  
len(data_dict1)
# Out:
# 1018

# %%
# normalization indonesian words
normalized_word = pd.read_csv('dataset/new_kamusalay.csv', header=None)
data_dict2 = dict(zip(normalized_word[0], normalized_word[1]))
len(data_dict2)
# Out:
# 15166

# %%
def normalize_text1(text):
    return ' '.join(data_dict1.get(word, word) for word in text.split())
def normalize_text2(text):
    return ' '.join(data_dict2.get(word, word) for word in text.split())

# %%
df['tweet_normalized1'] = df['tweet_clean'].apply(lambda x: normalize_text1(x))
df['tweet_normalized2'] = df['tweet_normalized1'].apply(lambda x: normalize_text1(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized1  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized2
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
# [722 rows x 6 columns]

# %%
# stemming 'kata berimbuhan'
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['tweet_stemmed'] = df['tweet_normalized2'].apply(lambda x: stemmer.stem(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized1  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized2  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                           tweet_stemmed
# 0                            wifi watcha pasti indihome
# 1                           indihome ada masalah apasih
# 2     sore sore hujan rebah bareng bocil nonton nuss...
# 3              indihome plis untuk tanggal jangan surup
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min kalau jatuh tempo bayar ind...
# 995   xxxindihomexxx min indihome tv bisa gak langga...
# 997   xxxindihomexxx xxxuserxxx dari semalem down ga...
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002          xxxindihomexxx daftar indihome lewat mana
#
# [722 rows x 7 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Before we fit the clean data to the model, let's explore insights from the data we have.

# %%
from collections import Counter

# function to count unique words
def counter_word(text):
    count = Counter()
    for sentence in text.values:
        for word in sentence.split():
            count[word] += 1
    return count

# %%
# find out how many unique words in our data
unique_words = counter_word(df['tweet_stemmed'])
len(unique_words)
# Out:
# 2233

# %%
# take a look at the twenty most common words
unique_words.most_common(20)
# Out:
# [('indihome', 615),
#  ('xxxindihomexxx', 320),
#  ('xxxuserxxx', 318),
#  ('ini', 168),
#  ('di', 146),
#  ('saya', 143),
#  ('yang', 142),
#  ('kalau', 102),
#  ('sudah', 95),
#  ('pakai', 95),
#  ('dan', 88),
#  ('ada', 85),
#  ('banget', 84),
#  ('bisa', 81),
#  ('lagi', 76),
#  ('hari', 69),
#  ('saja', 67),
#  ('ga', 66),
#  ('tidak', 66),
#  ('juga', 62)]

# %%
# create a frequency table of word frequency
freq = [freq for word, freq in unique_words.items()]
top_unique=max(pd.Series(freq).value_counts())
top_unique
# Out:
# 1292

# %%
# your code here
sentence_length = df['tweet_stemmed'].apply(lambda x: len(x.split()))

# %%
# seaborn
sns.histplot(sentence_length, binwidth=1)
# Out:
# <AxesSubplot:xlabel='tweet_stemmed', ylabel='Count'>

# %%
# five number summary
sentence_length.describe()
# Out:
# count    722.000000
# mean      14.344875
# std       10.490940
# min        2.000000
# 25%        6.000000
# 50%       11.000000
# 75%       19.000000
# max       47.000000
# Name: tweet_stemmed, dtype: float64

# %%
# define number of words to keep during conversion (can be tuned)
num_words = len(unique_words)-top_unique
num_words
# Out:
# 941

# %% [markdown]
# ## Bidirectional GRU Model with Random Embedding

# %%
# Define a function to compute the max length of sequence
def max_length(sequences):
    '''
    input:
        sequences: a 2D list of integer sequences
    output:
        max_length: the max length of the sequences
    '''
    max_length = 0
    for i, seq in enumerate(sequences):
        length = len(seq)
        if max_length < length:
            max_length = length
    return max_length

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.constraints import MaxNorm

def define_model(input_dim = None, output_dim=300, max_length = None ):
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Embedding(input_dim=input_dim, 
                                  mask_zero= True,
                                  output_dim=output_dim, 
                                  input_length=max_length, 
                                  input_shape=(max_length, )),
        tf.keras.layers.Bidirectional((tf.keras.layers.GRU(units=64, return_sequences=True))),
        tf.keras.layers.Bidirectional((tf.keras.layers.GRU(units=64, return_sequences=False))),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=7, activation='sigmoid')
    ])
    
    model.compile( loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
class myCallback(tf.keras.callbacks.Callback):
    # Overide the method on_epoch_end() for our benefit
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('accuracy') > 0.93):
            print("\nReached 93% accuracy so cancelling training!")
            self.model.stop_training=True


callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0, 
                                             patience=10, verbose=2, 
                                             mode='auto', restore_best_weights=True)

# %% [markdown]
# ## Train and Test the model Using 10-Fold cross validation

# %%
from keras.utils.np_utils import to_categorical
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# Parameter Initialization
trunc_type='post'
padding_type='post'
oov_tok = "<UNK>"

columns = ['acc1', 'acc2', 'acc3', 'acc4', 'acc5', 'acc6', 'acc7', 'acc8', 'acc9', 'acc10', 'AVG']
record = pd.DataFrame(columns = columns)

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(n_splits=10, shuffle=False, random_state=None)

# Separate the tweet and label
tweets, labels = list(df.tweet_stemmed), list(df.label)

exp=0

# kfold.split() will return set indices for each split
acc_list = []
for train, test in kfold.split(tweets):
    
    exp+=1
    print('Training {}: '.format(exp))
    
    train_x, test_x = [], []
    train_y, test_y = [], []

    for i in train:
        train_x.append(tweets[i])
        train_y.append(labels[i])

    for i in test:
        test_x.append(tweets[i])
        test_y.append(labels[i])

    # Turn the labels into a numpy array
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # one-hot
    onehot_train_y = to_categorical(train_y)
    onehot_test_y = to_categorical(test_y)

    # encode data using Cleaning and Tokenization
    tokenizer = Tokenizer(num_words=num_words,oov_token=oov_tok)
    tokenizer.fit_on_texts(train_x)

    # Turn the text into sequence
    training_sequences = tokenizer.texts_to_sequences(train_x)
    test_sequences = tokenizer.texts_to_sequences(test_x)

    max_len = max_length(training_sequences)

    # Pad the sequence to have the same size
    Xtrain = pad_sequences(training_sequences, maxlen=max_len, padding=padding_type, truncating=trunc_type)
    Xtest = pad_sequences(test_sequences, maxlen=max_len, padding=padding_type, truncating=trunc_type)

    word_index = tokenizer.word_index
    vocab_size = len(word_index)+1

    # Define the input shape
    model = define_model(input_dim=vocab_size, max_length=max_len)

    # Train the model
    model.fit(Xtrain, onehot_train_y, batch_size=32, epochs=30, verbose=1, 
              callbacks=[callbacks], validation_data=(Xtest, onehot_test_y))

    # evaluate the model
    loss, acc = model.evaluate(Xtest, onehot_test_y, verbose=0)
    print('Test Accuracy: {}'.format(acc*100))

    acc_list.append(acc*100)

mean_acc = np.array(acc_list).mean()
entries = acc_list + [mean_acc]

temp = pd.DataFrame([entries], columns=columns)
record = record.append(temp, ignore_index=True)
print()
print(record)
print()
# Out:
# Training 1:
# Epoch 1/30
# 21/21 [==============================] - 16s 229ms/step - loss: 1.8704 - accuracy: 0.2681 - val_loss: 1.9851 - val_accuracy: 0.1644
# Epoch 2/30
# 21/21 [==============================] - 1s 30ms/step - loss: 1.6178 - accuracy: 0.4114 - val_loss: 1.7905 - val_accuracy: 0.3973
# Epoch 3/30
# 21/21 [==============================] - 1s 31ms/step - loss: 1.2144 - accuracy: 0.5655 - val_loss: 1.6409 - val_accuracy: 0.3562
# Epoch 4/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.9133 - accuracy: 0.6687 - val_loss: 1.6807 - val_accuracy: 0.3699
# Epoch 5/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6678 - accuracy: 0.7781 - val_loss: 1.8381 - val_accuracy: 0.3151
# Epoch 6/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.4735 - accuracy: 0.8444 - val_loss: 2.1067 - val_accuracy: 0.3562
# Epoch 7/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.3311 - accuracy: 0.8968 - val_loss: 2.1487 - val_accuracy: 0.4384
# Epoch 8/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2268 - accuracy: 0.9260 - val_loss: 2.5295 - val_accuracy: 0.3973
# Epoch 9/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.2009 - accuracy: 0.9384 - val_loss: 2.6863 - val_accuracy: 0.3699
# Epoch 10/30
# 21/21 [==============================] - 1s 30ms/step - loss: 0.1724 - accuracy: 0.9384 - val_loss: 3.0302 - val_accuracy: 0.3425
# Epoch 11/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1562 - accuracy: 0.9430 - val_loss: 2.8112 - val_accuracy: 0.3836
# Epoch 12/30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.1336 - accuracy: 0.9569 - val_loss: 3.2830 - val_accuracy: 0.3836
# Epoch 13/30
# 21/21 [==============================] - 1s 31ms/step - loss: 0.
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1229 - accuracy: 0.9646 - val_loss: 3.0850 - val_accuracy: 0.4028
# Epoch 14/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9646Restoring model weights from the end of the best epoch: 4.
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1119 - accuracy: 0.9646 - val_loss: 3.3098 - val_accuracy: 0.3611
# Epoch 00014: early stopping
# Test Accuracy: 48.61111044883728
#
#         acc1       acc2  acc3       acc4  acc5       acc6       acc7  \
# 0  43.835616  49.315068  50.0  43.055555  50.0  59.722221  54.166669
#
#         acc8       acc9     acc10        AVG
# 0  59.722221  41.666666  48.61111  50.009513
# C:\Users\baktistr\AppData\Local\Temp\ipykernel_41636\2141468724.py:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   record = record.append(temp, ignore_index=True)

# %%
record
# Out:
#         acc1       acc2  acc3       acc4  acc5       acc6       acc7  \
# 0  43.835616  49.315068  50.0  43.055555  50.0  59.722221  54.166669
#
#         acc8       acc9     acc10        AVG
# 0  59.722221  41.666666  48.61111  50.009513

# %% [markdown]
# report = record
# report = report.to_excel('GRU.xlsx', sheet_name='random')

# %% [markdown]
# ## Predict new tweet

# %%
# define the preprocessing pipeline
def text_preprocessing(text):
    # case folding
    text = text.lower()
    
    # text cleansing
    text = text_cleansing(text)
    
    # text normalization
    text = normalize_text1(text)
    
     # text normalization
    text = normalize_text2(text)
    
    # stemming
    text = stemmer.stem(text)
    
    return text

# %%
# predicting a text
from keras.utils.np_utils import to_categorical

def text_predict(text):
    
    # preprocess
    text_cleaned = text_preprocessing(text)
    text_sequence = tokenizer.texts_to_sequences([text_cleaned])

    max_len= max_length(training_sequences)

    seq_padded = pad_sequences(text_sequence, maxlen=max_len, padding=padding_type, truncating=trunc_type)

    # prediction
    pred_proba = model.predict(seq_padded)

    result = np.argmax(pred_proba)

    return result

# %%
# predicting data set

df['tweet_predict'] = df['tweet_stemmed'].apply(lambda x: text_predict(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalo jatuh tempo pembayara...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized1  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                       tweet_normalized2  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3       indihome plis untuk tanggal , jangan kesurupan?
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   xxxindihomexxx min, kalau jatuh tempo pembayar...
# 995   xxxindihomexxx min, indihome tv bisa gak berla...
# 997   xxxindihomexxx xxxuserxxx dari semalem down .....
# 1000  xxxuserxxx sini indihome down dr semalem jam a...
# 1002         xxxindihomexxx daftar indihome lewat mana?
#
#                                           tweet_stemmed  tweet_predict
# 0                            wifi watcha pasti indihome              5
# 1                           indihome ada masalah apasih              2
# 2     sore sore hujan rebah bareng bocil nonton nuss...              1
# 3              indihome plis untuk tanggal jangan surup              2
# 4                                   indihome ngapasiiii              2
# ...                                                 ...            ...
# 994   xxxindihomexxx min kalau jatuh tempo bayar ind...              6
# 995   xxxindihomexxx min indihome tv bisa gak langga...              6
# 997   xxxindihomexxx xxxuserxxx dari semalem down ga...              5
# 1000  xxxuserxxx sini indihome down dr semalem jam a...              2
# 1002          xxxindihomexxx daftar indihome lewat mana              6
#
# [722 rows x 8 columns]

# %%
# confusion matrix  
# source: https://datatofish.com/confusion-matrix-python/

confusion_matrix = pd.crosstab(df['label'], df['tweet_predict'], rownames=['Actual'], colnames=['Predicted'])

sns.heatmap(confusion_matrix, annot=True)
plt.show()

# labels:
        #0: indirect complaint
        #1: remark
        #2: negative remark
        #3: direct compliment
        #4: direct complaint
        #5: none
        #6: inquiry
